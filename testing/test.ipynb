# %%
import spectra

# %%
spectra.uniform(0.05)

# %%
import hanashi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6107790849cf> in <module>
# ----> 1 import hanashi
#
# ModuleNotFoundError: No module named 'hanashi'

# %%
hanashi.check_exsiting_batch()
# Out:
# [(1,
#   1,
#   890,
#   0.0,
#   'http://192.168.1.100:2001',
#   '192.168.1.100',
#   '[0.241178997325747, 0.33729219444435926, 0.44691393074843955, 0.42898941521269723, 0.2487469667933918, 0.17182771927485752, 0.19483963959076905, 0.35829930409515093, 0.9999641214191779, 0.4384152905383771]'),
#  (1,
#   1,
#   891,
#   0.0,
#   'http://192.168.1.100:2001',
#   '192.168.1.100',
#   '[0.241178997325747, 0.33729219444435926, 0.44691393074843955, 0.42898941521269723, 0.2487469667933918, 0.17182771927485752, 0.19483963959076905, 0.35829930409515093, 0.9999641214191779, 0.4384152905383771]'),
#  (1,
#   1,
#   892,
#   0.0,
#   'http://192.168.1.100:2001',
#   '192.168.1.100',
#   '[0.1205894986628735, 0.16864609722217963, 0.22345696537421977, 0.21449470760634862, 0.1243734833966959, 0.08591385963742876, 0.09741981979538453, 0.17914965204757546, 0.49998206070958895, 0.21920764526918854]'),
#  (1,
#   1,
#   893,
#   0.0,
#   'http://192.168.1.100:2001',
#   '192.168.1.100',
# ...
